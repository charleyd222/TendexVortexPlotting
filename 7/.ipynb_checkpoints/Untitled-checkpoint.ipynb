# %%
from ctypes import *
import numpy as np

class mat(Structure):
    _fields_ = [('m', (c_double*3)*3)]

def read_off(x,y,z):
    mat_c = f(x,y,z)
    
    print(mat_c.m[0][0], mat_c.m[0][1], mat_c.m[0][2])
    print(mat_c.m[1][0], mat_c.m[1][1], mat_c.m[1][2])
    print(mat_c.m[2][0], mat_c.m[2][1], mat_c.m[2][2])

# %%
num_its = 1
delta_0 = 10e-2
h0 = 10e-2
safety = .9
ending_tolerance = .1
pos_color = 'red'
neg_color = 'blue'
icity = 1
R = 1
sigma = 1
vX = 1

# %%
f = CDLL("./cppScripts/TimeDependentTest").f
f.argtypes = [c_double, c_double, c_double]
f.restype = mat

# %%
read_off(-0.123,.345,1.0)
# Out:
# 1.8811371326446533 -1.2169923138571903e-05 0.00017609952192287892
# -1.2169923138571903e-05 1.8818621635437012 -0.0003212044248357415
# 0.00017609952192287892 -0.0003212044248357415 -0.0005778592312708497
# <__main__.c_double_Array_3 object at 0x107055a50> <__main__.c_double_Array_3 object at 0x107055ad0> <__main__.c_double_Array_3 object at 0x107055bd0>
